# %% [markdown]
# ### Name: CHUKWU EYRAM MARY
# ### Id: 10968152
# ### Department: FOOD PROCESS ENGINEERING

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import padnas, matplotlib and seaborn
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Load dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data.csv')

# %%
# View Data
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# View Data Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ## Task 1- Dealing with Null values and Duplicates
# - There are 10 null values in the data set. This implies that there are 10 rows with missing data.
# - Since the number of missing values is less than 1% of the entire dataset, the approach to deal with
#     the missing values is to delete them using the dropna() method

# %%
# Check for Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Checking for null values
df.isnull().sum()
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
print(f'Total number of null values = {df.isnull().sum().sum()}')
# Out:
# Total number of null values = 10

# %%
# Deleting Null Values
df = df.dropna(how='any')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1591 non-null   int64
#  1   fixed acidity         1591 non-null   float64
#  2   volatile acidity      1591 non-null   float64
#  3   citric acid           1591 non-null   float64
#  4   residual sugar        1591 non-null   float64
#  5   chlorides             1591 non-null   float64
#  6   free sulfur dioxide   1591 non-null   float64
#  7   total sulfur dioxide  1591 non-null   float64
#  8   density               1591 non-null   float64
#  9   pH                    1591 non-null   float64
#  10  sulphates             1591 non-null   float64
#  11  alcohol               1591 non-null   float64
#  12  quality               1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %% [markdown]
# ## Task 2- Statistical Inferences of entire data set

# %%
# Statistical Inferences
df.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %% [markdown]
# ##Task 3 Staistical Inference for each Columns

# %% [markdown]
# ### Alcohol

# %%
df['alcohol'].describe()
# Out:
# count    1591.000000
# mean       10.426053
# std         1.066706
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
sns.histplot(df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
alcohol_mean = df.alcohol.mean()
alcohol_mean
# Out:
# 10.42605279698303

# %%
col = df.alcohol > alcohol_mean

# %%
col.value_counts()
# Out:
# False    910
# True     681
# Name: alcohol, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of Alcohol content of Beverage stock')
plt.legend(title="Alcohol Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Chlorides

# %%
df['chlorides'].describe()
# Out:
# count    1591.000000
# mean        0.087500
# std         0.047175
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
sns.histplot(df['chlorides'])
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %%
chlorides_mean = df.chlorides.mean()
chlorides_mean
# Out:
# 0.08749968573224387

# %%
col = df.chlorides > chlorides_mean

# %%
col.value_counts()
# Out:
# False    1120
# True      471
# Name: chlorides, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of Choride content of Beverage stock')
plt.legend(title="Chloride Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Citric Acid

# %%
df['citric acid'].describe()
# Out:
# count    1591.000000
# mean        0.271477
# std         0.194807
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
sns.histplot(df['citric acid'])
# Out:
# <Axes: xlabel='citric acid', ylabel='Count'>

# %%
ca_mean = df['citric acid'].mean()
ca_mean
# Out:
# 0.27147705845380266

# %%
col = df['citric acid'] > ca_mean
col
# Out:
# 0       False
# 1       False
# 3        True
# 4       False
# 5       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599     True
# 1600     True
# Name: citric acid, Length: 1591, dtype: bool

# %%
col.value_counts()
# Out:
# False    847
# True     744
# Name: citric acid, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of citric acid content of Beverage stock')
plt.legend(title="citric acid Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Fixed acidity

# %%
df['fixed acidity'].describe()
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
sns.histplot(df['fixed acidity'])
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Count'>

# %%
fi_mean = df['fixed acidity'].mean()
fi_mean
# Out:
# 8.32061596480201

# %%
col = df['fixed acidity'] > fi_mean
col
# Out:
# 0       False
# 1       False
# 3        True
# 4       False
# 5       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Name: fixed acidity, Length: 1591, dtype: bool

# %%
col.value_counts()
# Out:
# False    965
# True     626
# Name: fixed acidity, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of Fixed acidity content of Beverage stock')
plt.legend(title="fixed acidity Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### free sulfur dioxide

# %%
df['free sulfur dioxide'].describe()
# Out:
# count    1591.000000
# mean       15.861722
# std        10.429385
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
sns.histplot(df['free sulfur dioxide'])
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='Count'>

# %%
fr_mean = df['free sulfur dioxide'].mean()
fr_mean
# Out:
# 15.861722187303583

# %%
col = df['free sulfur dioxide'] > fr_mean
col
# Out:
# 0       False
# 1        True
# 3        True
# 4       False
# 5       False
#         ...
# 1596     True
# 1597     True
# 1598     True
# 1599     True
# 1600     True
# Name: free sulfur dioxide, Length: 1591, dtype: bool

# %%
col.value_counts()
# Out:
# False    918
# True     673
# Name: free sulfur dioxide, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of Free sulfur dioxide content of Beverage stock')
plt.legend(title="free sulfur dioxide Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### pH

# %%
df['pH'].describe()
# Out:
# count    1591.000000
# mean        3.311358
# std         0.154548
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
sns.histplot(df['pH'])
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
pH_mean = df['pH'].mean()
pH_mean
# Out:
# 3.3113576367064743

# %%
col = df['pH'] > pH_mean
col
# Out:
# 0        True
# 1       False
# 3       False
# 4        True
# 5        True
#         ...
# 1596     True
# 1597     True
# 1598     True
# 1599     True
# 1600    False
# Name: pH, Length: 1591, dtype: bool

# %%
col.value_counts()
# Out:
# False    817
# True     774
# Name: pH, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of pH content of Beverage stock')
plt.legend(title="pH Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %%
df['quality'].describe()
# Out:
# count    1591.000000
# mean        5.637964
# std         0.807772
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
sns.histplot(df['quality'])
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
qu_mean = df['quality'].mean()
qu_mean
# Out:
# 5.637963544940289

# %%
col = df['quality'] > qu_mean
col
# Out:
# 0       False
# 1       False
# 3        True
# 4       False
# 5       False
#         ...
# 1596     True
# 1597     True
# 1598    False
# 1599     True
# 1600     True
# Name: quality, Length: 1591, dtype: bool

# %%
col.value_counts()
# Out:
# True     854
# False    737
# Name: quality, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of quality content of Beverage stock')
plt.legend(title="quality Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### residual sugar

# %%
df['residual sugar'].describe()
# Out:
# count    1591.000000
# mean        2.540761
# std         1.413076
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
sns.histplot(df['residual sugar'])
# Out:
# <Axes: xlabel='residual sugar', ylabel='Count'>

# %%
re_mean = df['residual sugar'].mean()
re_mean
# Out:
# 2.5407605279698307

# %%
col = df['residual sugar'] > re_mean
col
# Out:
# 0       False
# 1        True
# 3       False
# 4       False
# 5       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599     True
# 1600     True
# Name: residual sugar, Length: 1591, dtype: bool

# %%
col.value_counts()
# Out:
# False    1156
# True      435
# Name: residual sugar, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of residual content of Beverage stock')
plt.legend(title="residual sugar Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### sulphates

# %%
df['sulphates'].describe()
# Out:
# count    1591.000000
# mean        0.658611
# std         0.169786
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
sns.histplot(df['sulphates'])
# Out:
# <Axes: xlabel='sulphates', ylabel='Count'>

# %%
su_mean = df['sulphates'].mean()
su_mean
# Out:
# 0.6586109365179132

# %%
col = df['sulphates'] > su_mean
col
# Out:
# 0       False
# 1        True
# 3       False
# 4       False
# 5       False
#         ...
# 1596     True
# 1597     True
# 1598     True
# 1599     True
# 1600     True
# Name: sulphates, Length: 1591, dtype: bool

# %%
col.value_counts()
# Out:
# False    956
# True     635
# Name: sulphates, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of sulphates of Beverage stock')
plt.legend(title="sulphates Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Total sulfur dioxide

# %%
df['total sulfur dioxide'].describe()
# Out:
# count    1591.000000
# mean       46.498429
# std        32.998659
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
sns.histplot(df['total sulfur dioxide'])
# Out:
# <Axes: xlabel='total sulfur dioxide', ylabel='Count'>

# %%
to_mean = df['total sulfur dioxide'].mean()
to_mean
# Out:
# 46.49842866121936

# %%
col = df['total sulfur dioxide'] > to_mean
col
# Out:
# 0       False
# 1        True
# 3        True
# 4       False
# 5       False
#         ...
# 1596     True
# 1597    False
# 1598    False
# 1599    False
# 1600     True
# Name: total sulfur dioxide, Length: 1591, dtype: bool

# %%
col.value_counts()
# Out:
# False    971
# True     620
# Name: total sulfur dioxide, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of total sulfur dioxide of Beverage stock')
plt.legend(title="total sulfur dioxide Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %%
df['volatile acidity'].describe()
# Out:
# count    1591.000000
# mean        0.527681
# std         0.179045
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
sns.histplot(df['volatile acidity'])
# Out:
# <Axes: xlabel='volatile acidity', ylabel='Count'>

# %%
vo_mean = df['volatile acidity'].mean()
vo_mean
# Out:
# 0.5276807039597737

# %%
col = df['volatile acidity'] > vo_mean
col
# Out:
# 0        True
# 1        True
# 3       False
# 4        True
# 5        True
#         ...
# 1596     True
# 1597    False
# 1598     True
# 1599    False
# 1600    False
# Name: volatile acidity, Length: 1591, dtype: bool

# %%
col.value_counts()
# Out:
# False    812
# True     779
# Name: volatile acidity, dtype: int64

# %%
plt.pie(col.value_counts(), labels=col.value_counts())
plt.title('Pie Chart of volatile acidity of Beverage stock')
plt.legend(title="total volatile acidity Content",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ## Task 4 Showing data correlation against columns

# %% [markdown]
# The quality of wine describes how good a wine sample is. In this section we will try to see how each property of wine samples contribute to the quality of the wine by checking their correlation

# %% [markdown]
# ### Alcohol against Quality

# %%
df.plot(x='alcohol' ,y='quality', kind='scatter')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='alcohol', ylabel='quality'>

# %%
corr = df['alcohol'].corr(df['quality'])
corr
# Out:
# 0.4754440924263702

# %% [markdown]
# From the graph above, we an observe that there exists some kind of relationship between alcohol levels and the quality of the wine sample. This is supported by the correlation coefficient vakue of 0.475 which suggests a moderate relationship between the two quantites.

# %% [markdown]
# ### Chlorides against Quality

# %%
df.plot(x='chlorides' ,y='quality', kind='scatter')
# Out:
# <Axes: xlabel='chlorides', ylabel='quality'>

# %%
corr = df['chlorides'].corr(df['quality'])
corr
# Out:
# -0.12903609159441415

# %% [markdown]
# From this graph above can obesrve that there's a weak correlation between the chloride and the quality of the wine

# %% [markdown]
# ### Citric acid against quality

# %%
df.plot(x='citric acid' ,y='quality', kind='scatter')
# Out:
# <Axes: xlabel='citric acid', ylabel='quality'>

# %%
corr = df['citric acid'].corr(df['quality'])
corr
# Out:
# 0.22426276192635228

# %% [markdown]
# From the graph above, it can be estimated that citric acid

# %% [markdown]
# ### Fixed acidity against quality

# %%
df.plot(x='fixed acidity' ,y='quality', kind='scatter')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='fixed acidity', ylabel='quality'>

# %%
corr = df['fixed acidity'].corr(df['quality'])
corr
# Out:
# 0.12495781359635282

# %% [markdown]
# According to the graph and correlation coefficient, there is very little or no association between quality and fixed acidity as there is no fixed pattern

# %% [markdown]
# ### Free sulfur dioxide against quality

# %%
df.plot(x='free sulfur dioxide' ,y='quality', kind='scatter')
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='quality'>

# %%
corr = df['free sulfur dioxide'].corr(df['quality'])
corr
# Out:
# -0.04984288544178145

# %% [markdown]
# From the graph and correlation coefficient, there is a very weak association between the free sulphur dioxide content and quality of the wine sample

# %% [markdown]
# ### pH against Quality

# %%
df.plot(x='pH' ,y='quality', kind='scatter')
# Out:
# <Axes: xlabel='pH', ylabel='quality'>

# %%
corr = df['pH'].corr(df['quality'])
corr
# Out:
# -0.05807726494335962

# %% [markdown]
# From the graph and correlation coefficient, there's a very weak negative association between pH and quality of the wine samples

# %% [markdown]
# ### Residual sugar against Quality

# %%
df.plot(x='residual sugar' ,y='quality', kind='scatter')
# Out:
# <Axes: xlabel='residual sugar', ylabel='quality'>

# %%
corr = df['quality'].corr(df['residual sugar'])
corr
# Out:
# 0.01337713051751029

# %% [markdown]
# From the graph and correlation coefficient , there's a weak positive association between sugar content and quality.

# %% [markdown]
# ### Sulphates against quality

# %%
df.plot(x='sulphates' ,y='quality', kind='scatter')
# Out:
# <Axes: xlabel='sulphates', ylabel='quality'>

# %%
corr = df['sulphates'].corr(df['quality'])
corr
# Out:
# 0.2498775602554397

# %% [markdown]
# From this graph entand the correlation coefficient, there is a weak positve correlation between sulphates and quality attributes of the wine samples

# %% [markdown]
# ### Total sulfur oxide

# %%
df.plot(x='total sulfur dioxide' ,y='quality', kind='scatter')
# Out:
# <Axes: xlabel='total sulfur dioxide', ylabel='quality'>

# %%
corr = df['total sulfur dioxide'].corr(df['quality'])
corr
# Out:
# -0.18465138992796487

# %% [markdown]
# From the graph above and the correlation coefficient, there is a weak neagtive association between the total sulfur oxide concentration and the quality of the wine samples
